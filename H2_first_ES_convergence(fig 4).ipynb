# %%
import pandas as pd
from matplotlib import pyplot as plt


cm = 1/2.54
#plt.rcParams["figure.figsize"] = [7.00, 3.50]
#plt.rcParams["figure.autolayout"] = True
fig, axs = plt.subplots(1, 2, figsize=(30*cm, 15*cm),constrained_layout=True)



########### H2 1.0 ########################
plt.suptitle('Energy Convergence of First Excited State',fontweight='bold')

axs[0].set_title("(a) $\mathregular{H_{2}}$ at 1.0 $\AA$",fontweight='bold')
axs[0].set_xlabel('Number of Function Evaluations',fontweight='bold')
axs[0].set_ylabel('|E(method)-E(FCI)| (Ha)', fontweight='bold')

Es = -0.866600086589
#axs[0].axhline(y=-0.866600086589,c='black',linestyle='--',linewidth='2.5',label='FCI')

columns = ["GS", "ES1"]


#----------------------


df = pd.read_csv("singlet_gsd_H2_1.0_double.csv", usecols=columns)
#print("Contents in csv file:", df)

sing_ref_two = list() 
x = list()
for i in range(len(df.ES1)):
    x.append(i+1)
    sing_ref_two.append(abs(Es-df.ES1[i]))


axs[0].plot(x, sing_ref_two,linewidth=2.4,c='grey',label='SingER 2-UCCGSD')

#----------------------------


df = pd.read_csv("singlet_gsd_H2_1.0.csv", usecols=columns)
#print("Contents in csv file:", df)

sing_ref_one = list() 
x = list()
for i in range(len(df.ES1)):
    x.append(i+1)
    sing_ref_one.append(abs(Es-df.ES1[i]))



axs[0].plot(x, sing_ref_one,linewidth=2.4,c='orange',label='SingER 1-UCCGSD')

#---------------------------------

df = pd.read_csv("triplet_gsd_H2_1.0.csv", usecols=columns)
#print("Contents in csv file:", df)

trip_ref_one = list() 
x = list()
for i in range(len(df.ES1)):
    x.append(i+1)
    trip_ref_one.append(abs(Es-df.ES1[i]))

axs[0].plot(x, trip_ref_one,linewidth=2.4,c='red',label='TripER 1-UCCGSD')

#-----------------------------------

df = pd.read_csv("single_gsd_H2_1.0.csv", usecols=columns)
#print("Contents in csv file:", df)

sing_ref_one = list() 
x = list()
for i in range(len(df.ES1)):
    x.append(i+1)
    sing_ref_one.append(abs(Es-df.ES1[i]))


### single det 


axs[0].plot(x, sing_ref_one,linewidth=2.4,c='m',label='SER 1-UCCGSD')

#-----------------------
## Dob det

df = pd.read_csv("double_gsd_H2_1.0.csv", usecols=columns)
#print("Contents in csv file:", df)

sing_ref_one = list() 
x = list()
for i in range(len(df.ES1)):
    x.append(i+1)
    sing_ref_one.append(abs(Es-df.ES1[i]))

axs[0].plot(x, sing_ref_one,linewidth=2.4,c='g',label='SER 2-UCCGSD')

#---------------------------------

df = pd.read_csv("SSSA_H2_1.0_1.csv", usecols=columns)
#print("Contents in csv file:", df)

sing_ref_one = list() 
x = list()
for i in range(len(df.GS)):
    x.append(i+1)
    sing_ref_one.append(abs(Es-df.GS[i]))



axs[0].plot(x, sing_ref_one,linewidth=2.4,c='navy',label='SS-SSSA-VQE')

axs[0].axhspan(0.0016, 0.00000, color = 'skyblue', alpha=0.5)    

axs[0].set_yscale("log")

axs[0].grid(alpha =0.75,linestyle='--')



'''
ins_ax1 = axs[0].inset_axes([.042, .032, .3, .3])  # [x, y, width, height] w.r.t. ax
ins_ax1.grid(alpha=1)

#ins_ax1.axhline(y=-0.866600086589,c='black',linestyle='--',linewidth='2.5')

ins_ax1.plot(x, sing_ref_one,linewidth=2.4,c='green',label='SS-SSSA-VQE')

ins_ax1.set_yscale('log')
#ins_ax1.plot(xxx, trip_ref_one,linewidth=2.4,c='red',label='Triplet-Ref')
ins_ax1.set_xticks([])
ins_ax1.set_yticks([])

#ins_ax1.grid(alpha=1)
#ins_ax1.axhline(y=-0.75397633,c='black',linestyle='--',linewidth='2.5')
'''

ins_ax = axs[0].inset_axes([.35, .06, .4, .4])  # [x, y, width, height] w.r.t. ax

cnot = []
import numpy as np
x = np.arange(1)
width=0.08
#ins_ax.grid(alpha=0.25)

ins_ax.bar(x-0.25,739,width,color='navy')
ins_ax.bar(x-0.15,2672,width,color='r')
ins_ax.bar(x-0.05,2672,width,color='orange')
ins_ax.bar(x+0.05,2672,width,color='m')
ins_ax.bar(x+0.15,5344,width,color='grey')
ins_ax.bar(x+0.25,5344,0.08,color='g')
#ins_ax.grid(alpha=0.5)
ins_ax.set_xticks([])
ins_ax.set_ylabel('CNOT Counts',fontweight='bold')
ins_ax.set_xlabel('Methods',fontweight='bold')
################################################################################
##################################---------------------------_______________##############################################
####################################333333333333333------------------------------------------ H2- 2.0 ######################################3

########### H2 2.0 ########################

axs[1].set_title("(b) $\mathregular{H_{2}}$ at 2.0 $\AA$",fontweight='bold')
axs[1].set_xlabel('Number of Function Evaluations',fontweight='bold')
axs[1].set_ylabel('|E(method)-E(FCI)| (Ha)', fontweight='bold')


Es = -0.986329933611
#axs[0].axhline(y=-0.866600086589,c='black',linestyle='--',linewidth='2.5',label='FCI')

columns = ["GS", "ES1"]


#----------------------


df = pd.read_csv("singlet_gsd_H2_2.0_double.csv", usecols=columns)
#print("Contents in csv file:", df)

sing_ref_two = list() 
x = list()
for i in range(len(df.ES1)):
    x.append(i+1)
    sing_ref_two.append(abs(Es-df.ES1[i]))


axs[1].plot(x, sing_ref_two,linewidth=2.4,c='grey',)#label='Singlet-Ref Repeat Unitary')

#----------------------------


df = pd.read_csv("singlet_gsd_H2_2.0.csv", usecols=columns)
#print("Contents in csv file:", df)

sing_ref_one = list() 
x = list()
for i in range(len(df.ES1)):
    x.append(i+1)
    sing_ref_one.append(abs(Es-df.ES1[i]))



axs[1].plot(x, sing_ref_one,linewidth=2.4,c='orange')#,label='Singlet-Ref')

#---------------------------------

df = pd.read_csv("triplet_gsd_H2_2.0.csv", usecols=columns)
#print("Contents in csv file:", df)

trip_ref_one = list() 
x = list()
for i in range(len(df.ES1)):
    x.append(i+1)
    trip_ref_one.append(abs(Es-df.ES1[i]))

axs[1].plot(x, trip_ref_one,linewidth=2.4,c='red',)#label='Triplet-Ref')

#-----------------------------------

df = pd.read_csv("single_gsd_H2_2.0.csv", usecols=columns)
#print("Contents in csv file:", df)

sing_ref_one = list() 
x = list()
for i in range(len(df.ES1)):
    x.append(i+1)
    sing_ref_one.append(abs(Es-df.ES1[i]))


### single det 


axs[1].plot(x, sing_ref_one,linewidth=2.4,c='m',)#label='Single-Det')

#-----------------------
## Dob det

df = pd.read_csv("double_gsd_H2_2.0.csv", usecols=columns)
#print("Contents in csv file:", df)

sing_ref_one = list() 
x = list()
for i in range(len(df.ES1)):
    x.append(i+1)
    sing_ref_one.append(abs(Es-df.ES1[i]))

axs[1].plot(x, sing_ref_one,linewidth=2.4,c='g',)#label='Single-Det Repeat Unitary')

#---------------------------------

df = pd.read_csv("SSSA_H2_2.0.csv", usecols=columns)
#print("Contents in csv file:", df)

sing_ref_one = list() 
x = list()
for i in range(len(df.GS)):
    x.append(i+1)
    sing_ref_one.append(abs(Es-df.GS[i]))



axs[1].plot(x, sing_ref_one,linewidth=2.4,c='navy')#,label='SSSA-VQE')

axs[1].axhspan(0.0016, 0.00000, color = 'skyblue', alpha=0.5)    

axs[1].set_yscale("log")

axs[1].grid(alpha =0.75,linestyle='--')



'''
ins_ax1 = axs[0].inset_axes([.042, .032, .3, .3])  # [x, y, width, height] w.r.t. ax
ins_ax1.grid(alpha=1)

#ins_ax1.axhline(y=-0.866600086589,c='black',linestyle='--',linewidth='2.5')

ins_ax1.plot(x, sing_ref_one,linewidth=2.4,c='green',label='SS-SSSA-VQE')

ins_ax1.set_yscale('log')
#ins_ax1.plot(xxx, trip_ref_one,linewidth=2.4,c='red',label='Triplet-Ref')
ins_ax1.set_xticks([])
ins_ax1.set_yticks([])

#ins_ax1.grid(alpha=1)
#ins_ax1.axhline(y=-0.75397633,c='black',linestyle='--',linewidth='2.5')
'''

ins_ax = axs[1].inset_axes([.39, .06, .4, .4])  # [x, y, width, height] w.r.t. ax

cnot = []
import numpy as np
x = np.arange(1)
width=0.08
#ins_ax.grid(alpha=0.25)

ins_ax.bar(x-0.25,739,width,color='navy')
ins_ax.bar(x-0.15,2672,width,color='r')
ins_ax.bar(x-0.05,2672,width,color='orange')
ins_ax.bar(x+0.05,2672,width,color='m')
ins_ax.bar(x+0.15,5344,width,color='grey')
ins_ax.bar(x+0.25,5344,0.08,color='g')
#ins_ax.grid(alpha=0.5)
ins_ax.set_xticks([])
ins_ax.set_ylabel('CNOT Counts',fontweight='bold')
ins_ax.set_xlabel('Methods',fontweight='bold')


fig.tight_layout()
fig.subplots_adjust(bottom=0.18)
#fig.legend(loc='center right',bbox_to_anchor=(1.0, 0.5),fancybox=True, shadow=True,ncol=1)
fig.legend(loc='lower center',bbox_to_anchor=(0.5, 0.0005),fancybox=True, shadow=True,ncol=3)
#plt.yscale('log')
#plt.legend()

plt.savefig('H4_com4.png',dpi=600)

plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_3712\2256234966.py:310: UserWarning: This figure was using constrained_layout, but that is incompatible with subplots_adjust and/or tight_layout; disabling constrained_layout.
#   fig.tight_layout()
